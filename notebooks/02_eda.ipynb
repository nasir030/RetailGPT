# %% [markdown]
# # 02 - Exploratory Data Analysis

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
import pandas as pd
import plotly.express as px
from backend.services.data_service import load_data

df = load_data()
df.describe(include='all').T
# Out:
#                         count unique              top  freq  \
# Row ID                 9994.0    NaN              NaN   NaN
# Order ID                 9994   5009   CA-2017-100111    14
# Order Date               9994    NaN              NaN   NaN
# Ship Date                9994    NaN              NaN   NaN
# Ship Mode                9994      4   Standard Class  5968
# Customer ID              9994    793         WB-21850    37
# Customer Name            9994    793    William Brown    37
# Segment                  9994      3         Consumer  5191
# Country                  9994      1    United States  9994
# City                     9994    531    New York City   915
# State                    9994     49       California  2001
# Postal Code            9994.0    NaN              NaN   NaN
# Region                   9994      4             West  3203
# Product ID               9994   1862  OFF-PA-10001970    19
# Category                 9994      3  Office Supplies  6026
# ...

# %% [markdown]
# ## Sales & Profit distribution

# %%
px.histogram(df, x='Sales', nbins=50, title='Sales Distribution')

# %%
px.histogram(df, x='Profit', nbins=50, title='Profit Distribution')

# %% [markdown]
# ## Category / Region breakdown

# %%
df.groupby('Category')[['Sales','Profit']].sum()
# Out:
#                        Sales       Profit
# Category
# Furniture        741999.7953   18451.2728
# Office Supplies  719047.0320  122490.8008
# Technology       836154.0330  145454.9481

# %%
df.groupby('Region')[['Sales','Profit']].sum().sort_values('Sales', ascending=False)
# Out:
#                Sales       Profit
# Region
# West     725457.8245  108418.4489
# East     678781.2400   91522.7800
# Central  501239.8908   39706.3625
# South    391721.9050   46749.4303

# %% [markdown]
# ## Correlation matrix

# %%
df[['Sales','Quantity','Discount','Profit','Profit Margin']].corr()
# Out:
#                   Sales  Quantity  Discount    Profit  Profit Margin
# Sales          1.000000  0.200795 -0.028190  0.479064       0.003444
# Quantity       0.200795  1.000000  0.008623  0.066253      -0.005280
# Discount      -0.028190  0.008623  1.000000 -0.219487      -0.864452
# Profit         0.479064  0.066253 -0.219487  1.000000       0.223732
# Profit Margin  0.003444 -0.005280 -0.864452  0.223732       1.000000
